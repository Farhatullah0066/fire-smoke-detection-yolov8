# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 33.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 3.6 MB/s eta 0:00:00

# %%
import os
os.environ['KAGGLE_API_TOKEN'] = 'KGAT_7d37cc3d27b520a879c1402c5ae6f450'

# %%
# !kaggle datasets download -d sayedgamal99/smoke-fire-detection-yolo -p /content/data
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/sayedgamal99/smoke-fire-detection-yolo
# License(s): CC0-1.0
# ...
# 100% 2.84G/2.84G [00:25<00:00, 118MB/s]

# %%
# !unzip -q /content/data/smoke-fire-detection-yolo.zip -d /content/data

# %%
# !ls /content/data
# !ls /content/data/data
# Out:
# data  data.yaml  smoke-fire-detection-yolo.zip
# test  train  val

# %%
data_yaml_content = """path: /content/data
train: train/images
val: val/images
test: test/images

names:
  0: smoke
  1: fire

nc: 2
"""

with open('/content/data/data.yaml', 'w') as f:
    f.write(data_yaml_content)

print(open('/content/data/data.yaml').read())
# Out:
# path: /content/data
# train: train/images
# val: val/images
# test: test/images
#
# names:
#   0: smoke
#   1: fire
#
# nc: 2

# %%
# !rm /content/data/smoke-fire-detection-yolo.zip

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
    data='/content/data/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    name='fire_smoke_full',
    patience=15,
    plots=True,
    device=0   # use the GPU
)
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# ...
# Ultralytics 8.4.150 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls /content/data/val
# !ls /content/data/train
# !ls /content/data/test
# Out:
# ls: cannot access '/content/data/val': No such file or directory
# ls: cannot access '/content/data/train': No such file or directory
# ls: cannot access '/content/data/test': No such file or directory

# %%
# !ls -la /content/data
# Out:
# total 16
# drwxr-xr-x 3 root root 4096 Sep 13 07:23 .
# drwxr-xr-x 1 root root 4096 Sep 13 07:24 ..
# drwxr-xr-x 5 root root 4096 Sep 13 07:21 data
# -rw-r--r-- 1 root root  110 Sep 13 07:22 data.yaml

# %%
# !nvidia-smi
# Out:
# Sun Sep 13 07:27:55 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   59C    P0             28W /   70W |     105MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !ls /content
# Out:
# data  runs  sample_data  yolov8n.pt

# %%
# !ls /content/data/data
# Out:
# test  train  val

# %%
data_yaml_content = """path: /content/data/data
train: train/images
val: val/images
test: test/images

names:
  0: smoke
  1: fire

nc: 2
"""

with open('/content/data/data.yaml', 'w') as f:
    f.write(data_yaml_content)

print(open('/content/data/data.yaml').read())
# Out:
# path: /content/data/data
# train: train/images
# val: val/images
# test: test/images
#
# names:
#   0: smoke
#   1: fire
#
# nc: 2

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
    data='/content/data/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    name='fire_smoke_full',
    patience=15,
    plots=True,
    device=0
)
# Out:
# Ultralytics 8.4.150 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls /content/runs/detect/
# Out:
# fire_smoke_full  fire_smoke_full-2

# %%
from google.colab import files
files.download('/content/runs/detect/fire_smoke_full-2/weights/best.pt')

# %%
# !zip -r /content/results.zip /content/runs/detect/fire_smoke_full-2/
files.download('/content/results.zip')
# Out:
#   adding: content/runs/detect/fire_smoke_full-2/ (stored 0%)
#   adding: content/runs/detect/fire_smoke_full-2/val_batch1_labels.jpg (deflated 17%)
#   adding: content/runs/detect/fire_smoke_full-2/weights/ (stored 0%)
#   adding: content/runs/detect/fire_smoke_full-2/weights/best.pt (deflated 9%)
#   adding: content/runs/detect/fire_smoke_full-2/weights/last.pt (deflated 9%)
#   adding: content/runs/detect/fire_smoke_full-2/val_batch2_labels.jpg (deflated 11%)
#   adding: content/runs/detect/fire_smoke_full-2/labels.jpg (deflated 37%)
#   adding: content/runs/detect/fire_smoke_full-2/results.csv (deflated 68%)
#   adding: content/runs/detect/fire_smoke_full-2/confusion_matrix.png (deflated 31%)
#   adding: content/runs/detect/fire_smoke_full-2/val_batch0_pred.jpg (deflated 12%)
#   adding: content/runs/detect/fire_smoke_full-2/BoxR_curve.png (deflated 12%)
#   adding: content/runs/detect/fire_smoke_full-2/train_batch2.jpg (deflated 7%)
# ...
